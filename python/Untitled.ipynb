# %%
import matplotlib.pyplot as plt
import numpy

# %%
fig,ax = plt.subplots()
ax.plot([0,1],[0,1])
ax.patch.set_facecolor('#abcdef')
plt.savefig('/home/sia/test.pdf',transparent=True,bbox_inches='tight',facecolor=ax.get_facecolor())

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
